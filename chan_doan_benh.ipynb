# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('D:/Pandora Box/dataset benh.csv')
data.head()
# Out:
#    ID benh nhan  Dinh luong Ure (2.5-7.5 mmol/L) Danh gia  \
# 0           160                              1.9     Thap
# 1           173                              1.7     Thap
# 2            63                              2.2     Thap
# 3           263                              7.9      Cao
# 4            74                              1.8     Thap
#
#    Dinh luong Creatinin (60-104 mmol/L) Danh gia.1  \
# 0                                    30       Thap
# 1                                    29       Thap
# 2                                    49       Thap
# 3                                   129        Cao
# 4                                    41       Thap
#
#    Nong do glucose (50-200mg/dL) Danh gia.2  \
# 0                             18       Thap
# 1                             44       Thap
# 2                            212        Cao
# 3                             49       Thap
# 4                            223        Cao
#
#    Nong do acid uric ( 180-420 mmol/l) Danh gia.3  \
# 0                                  443        Cao
# 1                                  439        Cao
# 2                                  179       Thap
# 3                                  441        Cao
# 4                                  140       Thap
#
#    Luong glucose huyet thanh trung binh HbA1c (50-137mg/dL)  Danh gia.4  \
# 0                                                 93         Trung binh
# 1                                                129         Trung binh
# 2                                                186                Cao
# 3                                                 37               Thap
# 4                                                152                Cao
#
#    Dinh luong d nieu (protein nuoc tieu) 24 gio (50-200mg/l/24h) Danh gia.5  \
# 0                                                 34                   Thap
# 1                                                 13                   Thap
# 2                                                 22                   Thap
# 3                                                220                    Cao
# 4                                                 42                   Thap
#
#   Chan doan benh Phong kham So cho trong (1-10) So nguoi trong phong  \
# 0            Gut        102                   7                    3
# 1            Gut        103                   5                    5
# 2     Tieu duong        200                   3                    7
# 3       Suy than        301                   3                    7
# 4     Tieu duong        202                   2                    8
#
#                       DF Thoi gian kh TB (phut)  Thoi gian kham
# 0  [0, 0, 0 ,2, 1, 0, 1]                     10            9.01
# 1  [0, 0, 0 ,2, 1, 0, 1]                     22            9.11
# 2  [0, 0, 2, 0, 2, 0, 0]                     25            9.21
# 3  [2, 2, 0, 2, 0, 2, 2]                     17            9.31
# 4  [0, 0, 2, 0, 2, 0, 0]                     14            9.41

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 20 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   ID benh nhan                                                   350 non-null    int64
#  1   Dinh luong Ure (2.5-7.5 mmol/L)                                350 non-null    float64
#  2   Danh gia                                                       350 non-null    object
#  3   Dinh luong Creatinin (60-104 mmol/L)                           350 non-null    int64
#  4   Danh gia.1                                                     350 non-null    object
#  5   Nong do glucose (50-200mg/dL)                                  350 non-null    int64
#  6   Danh gia.2                                                     350 non-null    object
#  7   Nong do acid uric ( 180-420 mmol/l)                            350 non-null    int64
#  8   Danh gia.3                                                     350 non-null    object
#  9   Luong glucose huyet thanh trung binh HbA1c (50-137mg/dL)       350 non-null    int64
#  10  Danh gia.4                                                     350 non-null    object
#  11  Dinh luong d nieu (protein nuoc tieu) 24 gio (50-200mg/l/24h)  350 non-null    int64
#  12  Danh gia.5                                                     350 non-null    object
#  13  Chan doan benh                                                 350 non-null    object
#  14  Phong kham                                                     350 non-null    object
#  15  So cho trong (1-10)                                            350 non-null    object
#  16  So nguoi trong phong                                           350 non-null    object
#  17  DF                                                             350 non-null    object
#  18  Thoi gian kh TB (phut)                                         350 non-null    object
#  19  Thoi gian kham                                                 350 non-null    float64
# dtypes: float64(2), int64(6), object(12)
# memory usage: 54.8+ KB

# %% [markdown]
# Không có missing values.

# %%
data.describe()
# Out:
#        ID benh nhan  Dinh luong Ure (2.5-7.5 mmol/L)  \
# count    350.000000                       350.000000
# mean     174.500000                         4.976857
# std      101.180532                         2.974342
# min        0.000000                         1.000000
# 25%       87.250000                         2.300000
# 50%      174.500000                         4.300000
# 75%      261.750000                         7.875000
# max      349.000000                        10.500000
#
#        Dinh luong Creatinin (60-104 mmol/L)  Nong do glucose (50-200mg/dL)  \
# count                            350.000000                     350.000000
# mean                              82.380000                     141.897143
# std                               34.095537                      80.627416
# min                               21.000000                      16.000000
# 25%                               55.250000                      71.000000
# 50%                               81.000000                     140.000000
# 75%                              109.000000                     210.750000
# max                              145.000000                     290.000000
#
#        Nong do acid uric ( 180-420 mmol/l)  \
# count                           350.000000
# mean                            371.414286
# std                             118.375912
# min                             130.000000
# 25%                             269.750000
# 50%                             427.000000
# 75%                             460.000000
# max                             520.000000
#
#        Luong glucose huyet thanh trung binh HbA1c (50-137mg/dL)  \
# count                                         350.000000
# mean                                          100.557143
# std                                            50.878989
# min                                            15.000000
# 25%                                            54.000000
# 50%                                           101.500000
# 75%                                           144.000000
# max                                           189.000000
#
#        Dinh luong d nieu (protein nuoc tieu) 24 gio (50-200mg/l/24h)  \
# count                                         350.000000
# mean                                          128.240000
# std                                            78.902861
# min                                            12.000000
# 25%                                            44.250000
# 50%                                           130.000000
# 75%                                           204.750000
# max                                           249.000000
#
#        Thoi gian kham
# count      350.000000
# mean         6.727429
# std          3.503974
# min          1.010000
# 25%          3.510000
# 50%          6.460000
# 75%         10.010000
# max         12.510000

# %% [markdown]
# Các giá trị không có gì bất thường.

# %%
# Các features đã được xử lý thành categorical variables với 3 mức 'Thấp', 'Trung bình', 'Cao'.

cols_X = ['Danh gia', 'Danh gia.1', 'Danh gia.2', 'Danh gia.3', 'Danh gia.4', 'Danh gia.5']
col_y = ['Chan doan benh']

# %%
X = data[cols_X] # features
y = data[col_y] # target

# %%
# Xử lý các categorical variables thành numerical variables

label_encoder = LabelEncoder()

for col in cols_X:
    X[col] = label_encoder.fit_transform(X[col])

# %%
model = RandomForestClassifier(n_estimators=2, random_state=1)

# %%
from sklearn.model_selection import train_test_split

# Lấy 90% dữ liệu để train, 10% còn lại để test.

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.1)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=2, random_state=1)

# %%
# Dự đoán với 10% dữ liệu đã tách ra ở bên trên

preds = model.predict(X_test)

# %%
#So sánh kết quả dự đoán với kết quả gốc
from sklearn.metrics import accuracy_score

print(f'Độ chính xác: {accuracy_score(y_test, preds) * 100}%')
# Out:
# Độ chính xác: 100.0%

# %%
def chan_doan_benh(array):
    array = np.array(array)
    preds = model.predict(array.reshape(1, -1))
    if preds[0] == 'Gut':
        preds[0] = 'Gút'
    elif preds[0] == 'Tieu duong':
        preds[0] = 'Tiểu Đường'
    elif preds[0] == 'Suy than':
        preds[0] = 'Suy Thận'
    else:
        preds[0] = 'Không'
    print(f'Bạn có nguy cơ mắc bệnh {preds[0]}.')

# %% [markdown]
# <hr>
# <b> TEST Ở BÊN DƯỚI</b><br>
# <i>Input dưới dạng list<i>

# %%
chan_doan_benh([1,2,1,1,1,1])
# Out:
# Bạn có nguy cơ mắc bệnh Gút.

# %% [markdown]
# <hr>
